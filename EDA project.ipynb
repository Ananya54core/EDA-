# %% [markdown]
# # Exploratory Data Analysis on Healthcare

# %%
import pandas as pd 
import numpy as np 
import datetime
from time import strftime
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
data= pd.read_csv("C:\\Users\\anany\\OneDrive\\Desktop\\pandas\\Data.csv")
data
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
data.shape
# Out:
# (110527, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
data['ScheduledDay'] = pd.to_datetime(data['ScheduledDay']).dt.date
data['AppointmentDay']= pd.to_datetime(data['AppointmentDay']).dt.date
data
# Out:
#            PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0       2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1       5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2       4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3       8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4       8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
# ...              ...            ...    ...          ...            ...  ...
# 110522  2.572134e+12        5651768      F   2016-05-03     2016-06-07   56
# 110523  3.596266e+12        5650093      F   2016-05-03     2016-06-07   51
# 110524  1.557663e+13        5630692      F   2016-04-27     2016-06-07   21
# 110525  9.213493e+13        5630323      F   2016-04-27     2016-06-07   38
# 110526  3.775115e+14        5629448      F   2016-04-27     2016-06-07   54
#
# ...

# %%
data['ScheduledDay'] = pd.to_datetime(data['ScheduledDay'])
data['sch_weekly'] = data['ScheduledDay'].dt.dayofweek

# %%
data['AppointmentDay'] = pd.to_datetime(data['AppointmentDay'])
data['app_weekday'] = data['AppointmentDay'].dt.dayofweek
data
# Out:
#            PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0       2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1       5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2       4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3       8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4       8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
# ...              ...            ...    ...          ...            ...  ...
# 110522  2.572134e+12        5651768      F   2016-05-03     2016-06-07   56
# 110523  3.596266e+12        5650093      F   2016-05-03     2016-06-07   51
# 110524  1.557663e+13        5630692      F   2016-04-27     2016-06-07   21
# 110525  9.213493e+13        5630323      F   2016-04-27     2016-06-07   38
# 110526  3.775115e+14        5629448      F   2016-04-27     2016-06-07   54
#
# ...

# %%
data['sch_weekly'].value_counts()
# Out:
# sch_weekly
# 1    26168
# 2    24262
# 0    23085
# 4    18915
# 3    18073
# 5       24
# Name: count, dtype: int64

# %%
data['app_weekday'].value_counts()
# Out:
# app_weekday
# 2    25867
# 1    25640
# 0    22715
# 4    19019
# 3    17247
# 5       39
# Name: count, dtype: int64

# %%
data=data.rename(columns={"hipertension":"hypertension","Handcap":"Handicap","SMS_received":"SMSRecieved","No-show":"Noshow"})
data.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMSRecieved', 'Noshow',
#        'sch_weekly', 'app_weekday'],
#       dtype='object')

# %%
# Attempt to rename the columns
data= data.rename(columns={"hipertension": "hypertension", "Handcap": "Handicap", "SMS_received": "SMSReceived", "No-show": "Noshow"})

# Print the column names after renaming
print("\nColumn names after attempted renaming:")
print(data.columns)
# Out:
# Column names after attempted renaming:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMSRecieved', 'Noshow'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns]
#  4   AppointmentDay  110527 non-null  datetime64[ns]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handicap        110527 non-null  int64
#  12  SMSRecieved     110527 non-null  int64
#  13  Noshow          110527 non-null  object
#  14  sch_weekly      110527 non-null  int32
#  15  app_weekday     110527 non-null  int32
# ...

# %%
data.describe()
# Out:
#           PatientId  AppointmentID                   ScheduledDay  \
# count  1.105270e+05   1.105270e+05                         110527
# mean   1.474963e+14   5.675305e+06  2016-05-08 20:33:18.179630080
# min    3.921784e+04   5.030230e+06            2015-11-10 00:00:00
# 25%    4.172614e+12   5.640286e+06            2016-04-29 00:00:00
# 50%    3.173184e+13   5.680573e+06            2016-05-10 00:00:00
# 75%    9.439172e+13   5.725524e+06            2016-05-20 00:00:00
# max    9.999816e+14   5.790484e+06            2016-06-08 00:00:00
# std    2.560949e+14   7.129575e+04                            NaN
#
#                       AppointmentDay            Age    Scholarship  \
# count                         110527  110527.000000  110527.000000
# mean   2016-05-19 00:57:50.008233472      37.088874       0.098266
# min              2016-04-29 00:00:00      -1.000000       0.000000
# 25%              2016-05-09 00:00:00      18.000000       0.000000
# ...

# %%
data["Noshow"].value_counts().plot(kind="barh", figsize=(8, 6))
plt.xlabel("Count")
plt.ylabel("Target variable")
plt.title("Count of variable target per category")
# Out:
# Text(0.5, 1.0, 'Count of variable target per category')

# %%
# Having a look that data contains missing values or not
missing = pd.DataFrame((data.isnull().sum())*100/data.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index', y=0, data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
new_data= data.copy()
new_data
# Out:
#            PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0       2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1       5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2       4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3       8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4       8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
# ...              ...            ...    ...          ...            ...  ...
# 110522  2.572134e+12        5651768      F   2016-05-03     2016-06-07   56
# 110523  3.596266e+12        5650093      F   2016-05-03     2016-06-07   51
# 110524  1.557663e+13        5630692      F   2016-04-27     2016-06-07   21
# 110525  9.213493e+13        5630323      F   2016-04-27     2016-06-07   38
# 110526  3.775115e+14        5629448      F   2016-04-27     2016-06-07   54
#
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns]
#  4   AppointmentDay  110527 non-null  datetime64[ns]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handicap        110527 non-null  int64
#  12  SMSRecieved     110527 non-null  int64
#  13  Noshow          110527 non-null  object
#  14  sch_weekly      110527 non-null  int32
#  15  app_weekday     110527 non-null  int32
# ...

# %% [markdown]
# as we don't have any null values there is no cleaning data required

# %%
print(data["Age"].max())
# Out:
# 115

# %% [markdown]
# # Data Exploration

# %%
for i, predictor in enumerate(data.drop(columns=['No-show'])):
    print('-'*10,predictor,'-'*10)
    print(data[predictor].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 for i, predictor in enumerate(data.drop(columns=['No-show'])):
#       2     print('-'*10,predictor,'-'*10)
#       3     print(data[predictor].value_counts())
#
# File ~\anaconda\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
# ...

# %%
for i, predictor in enumerate(data.drop(columns=['No-show'])):
    print('-'*10,predictor,'-'*10)
    print(data[predictor].value_counts())
    plt.figure(i)
    sns.countplot(data=data, x=predictor, hue='No-show')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for i, predictor in enumerate(data.drop(columns=['No-show'])):
    plt.figure(i)
    sns.countplot(data=data, x=predictor, hue='No-show')
    plt.title(f'Countplot for {predictor} with No-show')
    plt.xlabel(predictor)
    plt.ylabel('Count')
    plt.legend(title='No-show')
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
import numpy as np

data['NoShow'] = np.where(data['No-show'] == 'Yes', 1, 0)

# %%
data['No-show'].value_counts()
# Out:
# No-show
# No     88208
# Yes    22319
# Name: count, dtype: int64

# %%
import pandas as pd
data_dummies = pd.get_dummies(data)
data_dummies.head()
# Out:
#       PatientId  AppointmentID  Age  Scholarship  Hipertension  Diabetes  \
# 0  2.987250e+13        5642903   62            0             1         0
# 1  5.589978e+14        5642503   56            0             0         0
# 2  4.262962e+12        5642549   62            0             0         0
# 3  8.679512e+11        5642828    8            0             0         0
# 4  8.841186e+12        5642494   56            0             1         1
#
#    Alcoholism  Handcap  SMS_received  Gender_F  ...  \
# 0           0        0             0      True  ...
# 1           0        0             0     False  ...
# 2           0        0             0      True  ...
# 3           0        0             0      True  ...
# 4           0        0             0      True  ...
#
#    Neighbourhood_SOLON BORGES  Neighbourhood_SÃO BENEDITO  \
# 0                       False                       False
# 1                       False                       False
# ...

# %%
sns.displot(data=data,x="Age",kde=True, rug=True,rug_kws={"height":0.05})
# Out:
# C:\Users\anany\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=data,x="Gender",y="Age",hue="AppointmentDay")
# Out:
# C:\Users\anany\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(15,15))

sns.boxplot(x="Age",y="Gender",data=data,linewidth=0.5, showmeans=True)
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
numeric_columns = sampled_data.select_dtypes(include=np.number)

# Perform correlation analysis on the numeric columns
correlation_matrix = numeric_columns.corr()

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 numeric_columns = sampled_data.select_dtypes(include=np.number)
#       3 # Perform correlation analysis on the numeric columns
#       4 correlation_matrix = numeric_columns.corr()
#
# NameError: name 'sampled_data' is not defined
